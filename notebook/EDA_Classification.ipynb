# %% [markdown]
# ### 1) Problem statement
# - To enhance the success of email campaigns, we aim to predict the Click Through Rate (CTR). CTR is the ratio of users who clicked on a Call to Action (CTA) to the number of emails delivered. Our goal is to create a smart system that predicts CTR, helping the marketing team identify crucial factors for maximizing user engagement.
#
#     Train and Test Set
#     Train and Test set contains different sets of email campaigns containing information about the email campaign. Train set includes the target variable click_rate and you need to predict the click_rate of an email campaign in the test set.
#
#     Variable - Description
#
#     campaign_id - Unique identifier of a campaign
#
#     sender - Sender of an e-mail
#
#     subject_len - No. of characters in a subject
#
#     body_len - No. of characters in an email body
#
#     mean_paragraph_len - Average no. of characters in paragraph of an email
#
#     day_of_week - Day on which email is sent
#
#     is_weekend - Boolean flag indicating if an email is sent on weekend or not
#
#     times_of_day - Times of day when email is sent: Morning, Noon, Evening
#
#     category - Category of the product an email is related to
#
#     product - Type of the product an email is related to
#
#     no_of_CTA - No. of Call To Actions in an email
#
#     mean_CTA_len - Average no. of characters in a CTA
#
#     is_image - No. of images in an email
#
#     is_personalised - Boolean flag indicating if an email is personalized to the user or not
#
#     is_quote - No. of quotes in an email
#
#     is_timer - Boolean flag indicating if an email contains a timer or not
#
#     is_emoticons - No. of emoticons in an email
#
#     is_discount - Boolean flag indicating if an email contains a discount or not
#
#     is_price - Boolean flag indicating if an email contains price or not
#
#     is_urgency - Boolean flag indicating if an email contains urgency or not
#
#     target_audience - Cluster label of the target audience
#
#     click_rate (Target Variable) - Click rate of an email campaign

# %% [markdown]
# ### 2) Data Collection
# - Dataset Source - https://www.kaggle.com/code/parisrohan/click-through-rate-prediction/input

# %% [markdown]
# ###  Import Data and Required Packages

# %% [markdown]
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import skew
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
df_train=pd.read_csv('data/train_F3fUq2S.csv')
df_test=pd.read_csv('data/test_Bk2wfZ3.csv')

# %% [markdown]
# Show top 5 records

# %%
df_train.head(5)
# Out:
#    campaign_id  sender  subject_len  body_len  mean_paragraph_len  \
# 0            1       3           76     10439                  39
# 1            2       3           54      2570                 256
# 2            3       3           59     12801                  16
# 3            4       3           74     11037                  30
# 4            5       3           80     10011                  27
#
#    day_of_week  is_weekend times_of_day  category  product  ...  is_image  \
# 0            5           1         Noon         6       26  ...         0
# 1            5           1      Morning         2       11  ...         0
# 2            5           1         Noon         2       11  ...         1
# 3            4           0      Evening        15        9  ...         0
# 4            5           1         Noon         6       26  ...         0
#
#    is_personalised  is_quote  is_timer  is_emoticons  is_discount  is_price  \
# ...

# %%
df_test.head(5)
# Out:
#    campaign_id  sender  subject_len  body_len  mean_paragraph_len  \
# 0         1889       3           61     12871                  11
# 1         1890       3           54      2569                 256
# 2         1891       3           88      1473                  78
# 3         1892       3           88      1473                  78
# 4         1893       3           78      9020                  29
#
#    day_of_week  is_weekend times_of_day  category  product  ...  mean_CTA_len  \
# 0            6           1         Noon         6       26  ...            37
# 1            5           1      Morning         2       11  ...            22
# 2            4           0      Evening         2       11  ...            22
# 3            3           0      Evening         2       11  ...            22
# 4            3           0         Noon         6       26  ...            40
#
#    is_image  is_personalised  is_quote  is_timer  is_emoticons  is_discount  \
# ...

# %% [markdown]
# ### 3. Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set

# %% [markdown]
# ### 3.1 Check Missing values

# %%
df_train.isnull().sum()
# Out:
# campaign_id           0
# sender                0
# subject_len           0
# body_len              0
# mean_paragraph_len    0
# day_of_week           0
# is_weekend            0
# times_of_day          0
# category              0
# product               0
# no_of_CTA             0
# mean_CTA_len          0
# is_image              0
# is_personalised       0
# is_quote              0
# is_timer              0
# is_emoticons          0
# is_discount           0
# is_price              0
# is_urgency            0
# target_audience       0
# click_rate            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# campaign_id           0
# sender                0
# subject_len           0
# body_len              0
# mean_paragraph_len    0
# day_of_week           0
# is_weekend            0
# times_of_day          0
# category              0
# product               0
# no_of_CTA             0
# mean_CTA_len          0
# is_image              0
# is_personalised       0
# is_quote              0
# is_timer              0
# is_emoticons          0
# is_discount           0
# is_price              0
# is_urgency            0
# target_audience       0
# dtype: int64

# %% [markdown]
# No null values in both test and train set

# %% [markdown]
# ### 3.2 Check Duplicates

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates in both train and test

# %% [markdown]
# ### 3.3 Check data types

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1888 entries, 0 to 1887
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   campaign_id         1888 non-null   int64
#  1   sender              1888 non-null   int64
#  2   subject_len         1888 non-null   int64
#  3   body_len            1888 non-null   int64
#  4   mean_paragraph_len  1888 non-null   int64
#  5   day_of_week         1888 non-null   int64
#  6   is_weekend          1888 non-null   int64
#  7   times_of_day        1888 non-null   object
#  8   category            1888 non-null   int64
#  9   product             1888 non-null   int64
#  10  no_of_CTA           1888 non-null   int64
#  11  mean_CTA_len        1888 non-null   int64
#  12  is_image            1888 non-null   int64
#  13  is_personalised     1888 non-null   int64
#  14  is_quote            1888 non-null   int64
#  15  is_timer            1888 non-null   int64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762 entries, 0 to 761
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   campaign_id         762 non-null    int64
#  1   sender              762 non-null    int64
#  2   subject_len         762 non-null    int64
#  3   body_len            762 non-null    int64
#  4   mean_paragraph_len  762 non-null    int64
#  5   day_of_week         762 non-null    int64
#  6   is_weekend          762 non-null    int64
#  7   times_of_day        762 non-null    object
#  8   category            762 non-null    int64
#  9   product             762 non-null    int64
#  10  no_of_CTA           762 non-null    int64
#  11  mean_CTA_len        762 non-null    int64
#  12  is_image            762 non-null    int64
#  13  is_personalised     762 non-null    int64
#  14  is_quote            762 non-null    int64
#  15  is_timer            762 non-null    int64
# ...

# %% [markdown]
# There is only one Categorical Column and rest are numerical columns in both test and train

# %% [markdown]
# ### 3.4 Checking the number of unique values of each column

# %%
df_train.nunique()
# Out:
# campaign_id           1888
# sender                  12
# subject_len            170
# body_len              1568
# mean_paragraph_len     121
# day_of_week              7
# is_weekend               2
# times_of_day             3
# category                16
# product                 43
# no_of_CTA               40
# mean_CTA_len            79
# is_image                 6
# is_personalised          2
# is_quote                 7
# is_timer                 1
# is_emoticons             6
# is_discount              2
# is_price                 8
# is_urgency               2
# target_audience         17
# click_rate            1810
# dtype: int64

# %%
df_test.nunique()
# Out:
# campaign_id           762
# sender                 12
# subject_len           129
# body_len              697
# mean_paragraph_len     83
# day_of_week             7
# is_weekend              2
# times_of_day            3
# category               16
# product                39
# no_of_CTA              25
# mean_CTA_len           59
# is_image                5
# is_personalised         2
# is_quote                6
# is_timer                1
# is_emoticons            7
# is_discount             2
# is_price                4
# is_urgency              2
# target_audience        16
# dtype: int64

# %%
from scipy.stats import ks_2samp

# for field in fields_to_compare:
_, p_value = ks_2samp(df_train['subject_len'], df_test['subject_len'])
print(f"KS Test p-value for {'subject_len'}: {p_value}")
# Out:
# KS Test p-value for subject_len: 0.9621135293565316

# %% [markdown]
# ### 3.5 Check statistics of data set

# %%
df_train['click_rate'].describe()
# Out:
# count    1888.000000
# mean        0.041888
# std         0.084223
# min         0.000000
# 25%         0.005413
# 50%         0.010686
# 75%         0.035589
# max         0.897959
# Name: click_rate, dtype: float64

# %% [markdown]
# Max Click rate is 89% and Mean click rate 4.1%

# %% [markdown]
# ### 4. Exploring Data ( Visualization )
# #### 4.1 Visualize features to make some conclusion.
# - Histogram
# - Kernel Distribution Function (KDE)

# %%
# lets plot CTR against campaign id
plt.figure(figsize=(22,6))
plt.plot(df_train['campaign_id'], df_train['click_rate'])
plt.title('click_rate per campaign_id')
plt.xlabel('campaign_id')
plt.ylabel('click_rate')

plt.show()

# %% [markdown]
# The presence of distinctive peaks in the CTR values associated with unique campaign IDs can have a significant impact on prediction models. Since each campaign ID is unique for the entire dataset, the model might perceive these IDs as categorical features with specific patterns or behaviors. Depending on the nature of the campaigns represented by these IDs, the model may attribute varying levels of importance to different campaigns.
#
#  Such data distribution makes this feature very skewed and can result in suboptimal performance of the regressor.

# %%
skewness = skew(df_train['click_rate'])
print(skewness)
# Out:
# 4.314311917527958

# %% [markdown]
# Askewness value of 4.3143 being positive suggests that the distribution of 'click_rate' is positively skewed,
#  indicating that there might be a longer tail on the right side of the distribution. This means there could be a few data
#  points with very high 'click_rate' values contributing to the skewness.

# %%
distinct_values = df_train.loc[df_train['is_weekend'] == 1, 'day_of_week'].unique()
print(distinct_values)
# Out:
# [5 6]

# %% [markdown]
# 5 and 6 indicate the weekend

# %%
plt.figure(figsize=(22,6))

plt.subplot(131)
sns.countplot(df_train,x='day_of_week',hue='day_of_week')

plt.subplot(132)
sns.countplot(df_train,x='times_of_day',hue='times_of_day')

plt.subplot(133)
sns.countplot(df_train,x='is_weekend',hue='is_weekend')
# Out:
# <Axes: xlabel='is_weekend', ylabel='count'>

# %% [markdown]
# Assume that the values 0-6 represent days from Sunday to Saturday. The majority of emails were sent on Wednesday, Tuesday, and Thursday. Additionally, a significant number of emails were sent during the evening, likely when people had more free time. If we categorize 0 as Not a Weekend and 1 as a Weekend, it's observed that most emails were sent on weekdays, with fewer emails sent on weekends.

# %%
plt.figure(figsize=(22,6))

plt.subplot(131)
sns.countplot(df_train,x='is_image',hue='is_image')

plt.subplot(132)
sns.countplot(df_train,x='is_quote',hue='is_quote')

plt.subplot(133)
sns.countplot(df_train,x='is_emoticons',hue='is_emoticons')
# Out:
# <Axes: xlabel='is_emoticons', ylabel='count'>

# %% [markdown]
# Assuming that the numbers 0 to 6 represent the frequency of certain features in an email, we observe that emails with 0-2 images are more common compared to those with 3-6 images. Similarly, emails with 0-1 quotes are more prevalent, while those with 2-6 quotes are less frequent. Additionally, emails with 0 emojis are more widespread, with occurrences decreasing for emails containing 1-6 emojis.

# %%
plt.figure(figsize=(22,6))

plt.subplot(141)
sns.countplot(df_train,x='is_personalised')

plt.subplot(142)
sns.countplot(df_train,x='is_discount')

plt.subplot(143)
sns.countplot(df_train,x='is_urgency')

plt.subplot(144)
sns.countplot(df_train,x='is_price')
# Out:
# <Axes: xlabel='is_price', ylabel='count'>

# %% [markdown]
# The majority of emails were not personalized, indicating they could be special discounts or offer emails. Conversely, a smaller number of emails were personalized, potentially indicating a connection to work-related content.
#
# Most emails did not fall under the category of discount emails, and fewer emails were categorized as discounted emails. This trend could be attributed to the likelihood of receiving discount emails during sales periods.
#
# Similarly, the majority of emails were not labeled as important or urgent, suggesting they might be related to routine matters. In contrast, a smaller proportion of emails were marked as urgency emails, potentially tied to work-related matters.
#
# We can drop these features as it is providing much of information

# %%
plt.figure(figsize=(22,6))

plt.subplot(131)
sns.countplot(df_train,x='sender')
# Out:
# <Axes: xlabel='sender', ylabel='count'>

# %% [markdown]
# category 3 is having maximum value while other categories having very less value.
# Even this feature doesn't provide much of information.

# %%
# boxplot and find distribution for subject_len
sns.boxplot(x=df_train['subject_len'])
# Out:
# <Axes: xlabel='subject_len'>

# %% [markdown]
# Number of character in subject lies between 25 words to 140 words approximately.
#
# While some of email campaigns have Number of character in subject aboove 150 and upto 250.

# %%
sns.boxplot(x=df_train['body_len'])
# Out:
# <Axes: xlabel='body_len'>

# %% [markdown]
# Number of character in body lies between up to 30000 words approximately.
#
# While some of email campaigns have Number of character in body above 30000 also.

# %%
sns.boxplot(x=df_train['mean_paragraph_len'])
# Out:
# <Axes: xlabel='mean_paragraph_len'>

# %% [markdown]
# Number of character in body lies between up to 70 approximately.
#
# While some of email campaigns have Number of character in body are above 70 and upto 300.

# %%
sns.boxplot(x=df_train['no_of_CTA'])
# Out:
# <Axes: xlabel='no_of_CTA'>

# %% [markdown]
# Value mostly lies between 0 and 9

# %% [markdown]
# no_of_CTA,mean_paragraph_len,body_len,subject_len we can perform outlier treatment on this USING IQR

# %%
len(df_train['product'].unique())
# Out:
# 43

# %% [markdown]
# Its categorical feature containing 43 unique values

# %%
len(df_train['category'].unique())
# Out:
# 16

# %% [markdown]
# Its categorical feature containing 16 unique values.

# %%
df_train['is_price'].unique()
# Out:
# array([    0,  5499,  8000,  4999,  1399,  5000,  1000, 14999])

# %%
df_train['is_price'].value_counts()
# Out:
# is_price
# 0        1875
# 5499        5
# 8000        2
# 5000        2
# 4999        1
# 1399        1
# 1000        1
# 14999       1
# Name: count, dtype: int64

# %% [markdown]
# Most of the values are from 0 Category and others let's us rename to 1 as there few different values

# %%
df_train['is_price']=np.where(df_train['is_price']==0,0,1)

# %%
df_train['is_price'].unique()
# Out:
# array([0, 1])

# %%
sns.countplot(data=df_train,x=df_train['is_price'])
# Out:
# <Axes: xlabel='is_price', ylabel='count'>

# %% [markdown]
# There feature doesn't provide much of information we ca drop this feature

# %%
df_train['is_timer'].value_counts()
# Out:
# is_timer
# 0    1888
# Name: count, dtype: int64

# %% [markdown]
# There is just one category doesn't provide much of information we can drop this feature.

# %%
# lets plot correlation between features
plt.subplots(figsize=(16,9))
numeric_df = df_train.select_dtypes(include='number')
correlation_mat = numeric_df.corr()
# sns.heatmap(correlation_mat, annot=True)
sns.heatmap(correlation_mat, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# Heatmap clearly suggests that it is a non linear data

# %%
df_train.select_dtypes(include='number').corrwith(df_train['click_rate']).sort_values(ascending=False)
# Out:
# click_rate            1.000000
# mean_paragraph_len    0.178042
# product               0.121602
# is_weekend            0.114138
# day_of_week           0.086372
# campaign_id           0.053315
# target_audience       0.038713
# is_personalised       0.032922
# is_image             -0.021527
# mean_CTA_len         -0.031162
# sender               -0.031398
# is_price             -0.031621
# is_discount          -0.086105
# is_emoticons         -0.094305
# is_quote             -0.098402
# is_urgency           -0.114284
# category             -0.167756
# no_of_CTA            -0.172637
# subject_len          -0.180143
# body_len             -0.247866
# is_timer                   NaN
# dtype: float64

# %% [markdown]
# Positive Correlation: If the correlation value is close to 1, it indicates a strong positive correlation. In our case , mean_paragraph_len, product, and is_weekend have positive correlations with click_rate. This means that as these features increase, the click_rate tends to increase as well.
#
# Negative Correlation: If the correlation value is close to -1, it indicates a strong negative correlation. In our case, subject_len, body_len, category, and no_of_CTA have negative correlations with click_rate. This means that as these features increase, the click_rate tends to decrease.
#
# Weak Correlation: Correlation values close to 0 suggest a weak or no linear correlation. For example, sender, is_price, is_discount, and is_quote have correlation values close to 0.
#
# NaN Correlation: The is_timer column has a NaN correlation with click_rate. This likely indicates that there is no numeric variation in the is_timer column, making it impossible to calculate a meaningful correlation.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# From above data analysis we came to know that some features are dominating in train dataset.
# Also if we can check statistically those features having very correlation with target features.
# Those features can ve dropeed from train and test data set.

# %%
df_train.drop(['is_personalised','is_timer','is_emoticons','is_discount','is_price','is_urgency','sender'], axis =1, inplace = True)
df_test.drop(['is_personalised','is_timer','is_emoticons','is_discount','is_price','is_urgency','sender'], axis =1, inplace = True)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (1888, 15)
# (762, 14)
